# %% [markdown]
# <a href="https://colab.research.google.com/github/JamesHop31/module-14-15-16-17/blob/main/first_activity14_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
filename = '/content/drive/MyDrive/Sampoleo,Marc James G./movies_metadata.csv'
df = pd.read_csv(filename)
# Out:
# <ipython-input-3-32ee7c271740>:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.Principal Paid
# Out:
#   File "<ipython-input-5-df2010422d5f>", line 1
#     df.Principal Paid
#                  ^
# SyntaxError: invalid syntax

# %%
# Approach 1 dictionary substitution using rename method
df = df.rename(columns={'Starting Balance': 'starting_balance',
'Interest Paid': 'interest_paid',
'Principal Paid': 'principal_paid'})
# DataFrame after renaming columns
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.columns=['id',
            'belongs_to_collection',
            'budget',
            'genres',
            'homepage',
            'adult',
            'original_language',
            'original_title',
            'release_date',
            'revenue',
            'runtime',
            'overview',
            'release_date',
            'runtime',
            'spoken_languages',
            'status',
            'tagline',
            'title',
            'video'
            'vote_average',
            'vote_count',
            'belongs_to_collection',
            'genres',
            'adult',
            'imdb_id']
df.head()
# Out:
#       id                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage  adult original_language  \
# 0  http://toystory.disney.com/toy-story    862         tt0114709
# 1                                   NaN   8844         tt0113497
# ...

# %%
df = df.drop(columns=['title'])
df.head()
# Out:
#       id                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage  adult original_language  \
# 0  http://toystory.disney.com/toy-story    862         tt0114709
# 1                                   NaN   8844         tt0113497
# ...

# %%
del df['genres']
df.head()

# %%
df.isna()

# %%
df.dropna(inplace=True)

# %%
df.dropna(subset=['runtime'], inplace=True)
df.isna().sum()
# Out:
# id                       0
# belongs_to_collection    0
# budget                   0
# homepage                 0
# adult                    0
# original_language        0
# original_title           0
# release_date             0
# revenue                  0
# runtime                  0
# overview                 0
# release_date             0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# videovote_average        0
# vote_count               0
# belongs_to_collection    0
# adult                    0
# imdb_id                  0
# dtype: int64

# %%
df.drop(columns='budget', inplace=True)
df.isna().sum()
# Out:
# id                       0
# belongs_to_collection    0
# homepage                 0
# adult                    0
# original_language        0
# original_title           0
# release_date             0
# revenue                  0
# runtime                  0
# overview                 0
# release_date             0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# videovote_average        0
# vote_count               0
# belongs_to_collection    0
# adult                    0
# imdb_id                  0
# dtype: int64

# %%
df.dropna(axis=1, inplace=True)

# %%
df.dropna(axis=1, thresh=.45, inplace=True)

# %%
df.dropna(axis=1, inplace=True)

# %%
df.dropna(axis=1, thresh=.45, inplace=True)

# %%
df['status'].fillna('Missing', inplace=True)

# %%
median_age = df['runtime'].median()
df['runtime'].fillna(median_age, inplace=False)
df.isna().sum()
# Out:
# <ipython-input-27-8edb3827c009>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   median_age = df['runtime'].median()
# id                       0
# belongs_to_collection    0
# homepage                 0
# adult                    0
# original_language        0
# original_title           0
# release_date             0
# revenue                  0
# runtime                  0
# overview                 0
# release_date             0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# videovote_average        0
# vote_count               0
# belongs_to_collection    0
# adult                    0
# imdb_id                  0
# dtype: int64

# %% [markdown]
# most_common_pet = df['genres'].mode()
# df['genres'].fillna(most_common_pet, inplace=True)

# %%
most_common_pet = df['adult'].mode()
df['adult'].fillna(most_common_pet, inplace=True)
# Out:
# <ipython-input-31-cfc5d6f3a1c3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['adult'].fillna(most_common_pet, inplace=True)
